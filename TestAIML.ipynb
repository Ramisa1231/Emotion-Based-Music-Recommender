# %% [markdown]
# <a href="https://colab.research.google.com/github/Ramisa1231/Emotion-Based-Music-Recommender/blob/emotion_recommender/TestAIML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
# !git clone https://github.com/Ramisa1231/Emotion-Based-Music-Recommender.git
# %cd Emotion-Based-Music-Recommender
# Out:
# /content
# Cloning into 'Emotion-Based-Music-Recommender'...
# remote: Enumerating objects: 99, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 99 (delta 13), reused 0 (delta 0), pack-reused 75 (from 1)
# Receiving objects: 100% (99/99), 22.10 MiB | 12.35 MiB/s, done.
# Resolving deltas: 100% (21/21), done.
# /content/Emotion-Based-Music-Recommender

# %%
# !python -m venv env
# !env\Scripts\activate # Windows
# Out:
# Error: Command '['/content/Emotion-Based-Music-Recommender/env/bin/python3', '-m', 'ensurepip', '--upgrade', '--default-pip']' returned non-zero exit status 1.
# /bin/bash: line 1: envScriptsactivate: command not found

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 79.5 MB/s eta 0:00:00
# ...

# %%
# !python manage.py migrate
# !python manage.py runserver
# Out:
# 2025-11-02 16:25:28.143939: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762100728.169214    1678 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762100728.176792    1678 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1762100728.195704    1678 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !ngrok config add-authtoken 34ullhLJLPXejYrmisf8M3lLRh5_4fMWv9gykFmWtadL2Sxce
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
from pyngrok import ngrok
public_url = ngrok.connect(8000).public_url
print("🌍 Public Django URL:", public_url)
# Out:
# 🌍 Public Django URL: https://nongrieving-georgeanna-nonapologetically.ngrok-free.dev
